# %%
#%pylab inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = linspace(0, 5, 10)

fig, ax = plt.subplots(facecolor='w', edgecolor='k')
ax.plot(x, sin(x), marker="o", color="r", linestyle='None')

ax.grid(True) #queremos verla cuadriculada
ax.set_xlabel('X') 
ax.set_ylabel('Y') 
ax.grid(True)
ax.legend(["y = x**2"])

plt.title("Puntos")
plt.show()

fig.savefig("gráfica.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 20) #generando 20 puntos entre 0 y 5
print(x) 
fig, ax = plt.subplots(facecolor='w', edgecolor='k')
ax.plot(x, np.sin(x), marker="o", color="r", linestyle='None') #esa "o" es por que queremos puntitos

ax.grid(True) #queremos verla cuadriculada
ax.set_xlabel('X') #etiqueta del eje x
ax.set_ylabel('Y') #etiqueta del eje y
ax.grid(True)
ax.legend("y = sen(x)")

plt.title("Función senoidal")
plt.show()
# Out:
# [0.         0.26315789 0.52631579 0.78947368 1.05263158 1.31578947
#  1.57894737 1.84210526 2.10526316 2.36842105 2.63157895 2.89473684
#  3.15789474 3.42105263 3.68421053 3.94736842 4.21052632 4.47368421
#  4.73684211 5.        ]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([50,100,150,200,250,300])
y = np.array([100,150,200,250,300,350])

plt.plot(x,y)

plt.title("support watch data")
plt.xlabel("y axcess")
plt.ylabel("y axcess")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#datos de entrada
x = np.linspace(0, 50, 50) #generando 50 puntos entre 0 y 50
fig, ax=plt.subplots(facecolor='w', edgecolor='k')
ax.plot(x, np.log(x), marker="x", color="r", linestyle='None') #esa "x" es por que queremos tachesitos

ax.grid(True) #queremos verla cuadriculada
ax.set_xlabel('X') #etiqueta del eje x
ax.set_ylabel('Y') #etiqueta del eje y
ax.grid(True)
ax.legend("y = log(x)")

plt.title("Función logaritmo")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#datos de entrada
x = np.linspace(0, 5, 20) #generando 50 puntos entre 0 y 50
fig, ax = plt.subplots(facecolor='w', edgecolor='k')
ax.plot(x, np.cos(x), marker="x", color="b", linestyle='None')

ax.grid(True)
ax.set_xlabel('X') #etiqueta del eje x
ax.set_ylabel('Y') #etiqueta del eje y
ax.grid(True)
ax.legend("y = cos(x)")

plt.title("Función cosenoidal")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#datos de entrada
x = np.linspace(0, 50, 50) #generando 50 puntos entre 0 y 50
fig, ax = plt.subplots(facecolor='w', edgecolor='k')
ax.plot(x, x, marker="x", color="b", linestyle='None')

ax.grid(True)
ax.set_xlabel('X') #etiqueta del eje x
ax.set_ylabel('Y') #etiqueta del eje y
ax.grid(True)
ax.legend("y = x")

plt.title("Función lineal")
plt.show()

# %%
x = range(0, 20)
y = [2 **v for v in x]
plt.plot(x, y)
plt.show()

# %%
x = range(-20, 20)
y = [v*v for v in x]
plt.plot(x, y)
plt.show()
